# %% [markdown]
# **01_double_it.md**

# %%
def magic_doubling(number):
    print("\n✨ Let the magic begin! ✨\n")
    while number < 100:
        number *= 2
        print(f"🔮 Poof! Your number is now: {number}")
    print("\n🎉 Boom! We've reached 100 or more! The magic ends here. 🎭")


print("🎩 Welcome to the Magic Doubling Machine! 🎩")
num = float(input("Enter a number: "))
magic_doubling(num)
# Out:
# 🎩 Welcome to the Magic Doubling Machine! 🎩
# Enter a number: 50
#
# ✨ Let the magic begin! ✨
#
# 🔮 Poof! Your number is now: 100.0
#
# 🎉 Boom! We've reached 100 or more! The magic ends here. 🎭
