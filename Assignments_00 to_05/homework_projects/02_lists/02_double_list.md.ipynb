# %% [markdown]
# **02_double_list.md**

# %%
import time
import random

def mystical_event():
    effects = [
        "✨ Ancient runes glow!",
        "🔮 A portal shimmers!",
        "🔥 Energy surges through the numbers!",
        "🌟 A hidden power awakens!",
        "💫 Cosmic forces align!"
    ]
    print(random.choice(effects))
    time.sleep(0.5)

def infinity_multiply(numbers):
    print("\n🔮 Summoning the Infinity Multiplier...\n")
    time.sleep(1)

    multiplied_numbers = []
    for num in numbers:
        mystical_event()
        multiplied = num * 2
        print(f"🔢 {num} → {multiplied} (Power Unleashed ✅)")
        multiplied_numbers.append(multiplied)
        time.sleep(0.5)

    print("\n⚡ The Infinity Multiplier has completed its work! Here’s your transformed list:")
    return multiplied_numbers

def main():
    print("\n🌟 Welcome to the Infinity Multiplier! ⚡")
    print("🔹 An ancient power lies within these numbers... ready to be unlocked!\n")

    user_input = input("🧙 Enter a list of numbers separated by spaces: ")
    numbers = [int(x) for x in user_input.split()]

    result = infinity_multiply(numbers)

    print("\n🌟 Final Enchanted List: ", result)
    print("\n🔮 Remember: True power is hidden in the simplest of numbers! ✨")

if __name__ == "__main__":
    main()
# Out:
# 🌟 Welcome to the Infinity Multiplier! ⚡
# 🔹 An ancient power lies within these numbers... ready to be unlocked!
#
# 🧙 Enter a list of numbers separated by spaces: 8 10 13 15 20 24 32
#
# 🔮 Summoning the Infinity Multiplier...
#
# 💫 Cosmic forces align!
# 🔢 8 → 16 (Power Unleashed ✅)
# 🔮 A portal shimmers!
# 🔢 10 → 20 (Power Unleashed ✅)
# 💫 Cosmic forces align!
# 🔢 13 → 26 (Power Unleashed ✅)
# 🔮 A portal shimmers!
# 🔢 15 → 30 (Power Unleashed ✅)
# ✨ Ancient runes glow!
# 🔢 20 → 40 (Power Unleashed ✅)
# 💫 Cosmic forces align!
# 🔢 24 → 48 (Power Unleashed ✅)
# 🔮 A portal shimmers!
# 🔢 32 → 64 (Power Unleashed ✅)
#
# ⚡ The Infinity Multiplier has completed its work! Here’s your transformed list:
#
# 🌟 Final Enchanted List:  [16, 20, 26, 30, 40, 48, 64]
#
# 🔮 Remember: True power is hidden in the simplest of numbers! ✨
