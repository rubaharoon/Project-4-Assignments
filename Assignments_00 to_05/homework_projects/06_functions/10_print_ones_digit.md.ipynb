# %% [markdown]
# **10_print_ones_digit.md**

# %%
import time
import random

def print_ones_digit(num):
    print("\n🔎 Analyzing the mysterious number... 🤔")
    time.sleep(1)

    suspense = ["💭 Breaking it down...", "🧮 Crunching the numbers...", "📊 Almost there!"]
    for s in suspense:
        print(s)
        time.sleep(random.uniform(0.5, 1.2))

    ones_digit = abs(num) % 10

    reactions = {
        0: "💥 Boom! It's a zero! Pure symmetry!",
        1: "🔢 A solid one! Small but mighty!",
        2: "🌟 Two's company, but you're number one!",
        3: "🎩 Three? That's a lucky number!",
        4: "🚀 Four! Almost halfway to greatness!",
        5: "🔥 Five! Smack dab in the middle!",
        6: "🌊 Six! Smooth and flowing!",
        7: "🎰 Seven! Jackpot vibes!",
        8: "💫 Eight! Infinity turned sideways!",
        9: "⚡ Nine! The highest of single digits!"
    }

    print(f"\n✨ The ones digit of {num} is **{ones_digit}**! {reactions[ones_digit]}\n")

def main():
    num = int(input("\n🔢 Enter a number: "))
    print_ones_digit(num)

# Run the program
main()
# Out:
# 🔢 Enter a number: 50
#
# 🔎 Analyzing the mysterious number... 🤔
# 💭 Breaking it down...
# 🧮 Crunching the numbers...
# 📊 Almost there!
#
# ✨ The ones digit of 50 is **0**! 💥 Boom! It's a zero! Pure symmetry!
