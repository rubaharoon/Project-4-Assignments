# %% [markdown]
# **01_chaotic_counting.md**

# %%
import random
import time

DONE_LIKELIHOOD = 0.3

def done():
    return random.random() < DONE_LIKELIHOOD

def chaotic_counting():
    print("\n⚡ Initiating Chaotic Counting! ⚡")
    time.sleep(1)

    for num in range(1, 11):
        if done():
            print(f"\n🚨 Chaos strikes at {num}! Stopping abruptly! 🚨")
            return

        print(f"🔢 Counting: {num}")
        time.sleep(random.uniform(0.3, 1.2))

    print("\n🎉 We made it to 10! Against all odds! 🎉")

def main():
    chaotic_counting()
    print("\nI'm done.")

# Run the program
main()
# Out:
# ⚡ Initiating Chaotic Counting! ⚡
# 🔢 Counting: 1
# 🔢 Counting: 2
# 🔢 Counting: 3
#
# 🚨 Chaos strikes at 4! Stopping abruptly! 🚨
#
# I'm done.
