# %% [markdown]
# **07_print_divisor.md**

# %%
import time

def print_divisors(num):
    print(f"\n🔎 Searching for the legendary divisors of {num}...\n")
    time.sleep(1)

    divisors = []

    for i in range(1, num + 1):
        if num % i == 0:
            divisors.append(i)
            print(f"✅ {i} is a divisor of {num}!")
            time.sleep(0.5)

    print("\n✨ Behold! The mighty divisors have been revealed! ✨")
    print(f"🎯 All divisors of {num}: {', '.join(map(str, divisors))}\n")

def main():
    num = int(input("\n🔢 Enter a number to find its divisors: "))
    print_divisors(num)

# Run the program
main()
# Out:
# 🔢 Enter a number to find its divisors: 4
#
# 🔎 Searching for the legendary divisors of 4...
#
# ✅ 1 is a divisor of 4!
# ✅ 2 is a divisor of 4!
# ✅ 4 is a divisor of 4!
#
# ✨ Behold! The mighty divisors have been revealed! ✨
# 🎯 All divisors of 4: 1, 2, 4
