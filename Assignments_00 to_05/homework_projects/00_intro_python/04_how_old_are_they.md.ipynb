# %% [markdown]
# **04_how_old_are_they.md**

# %%
def main():

    print("🎉 Welcome to the Age Riddle Solver! 🤔📅")
    print("Let's calculate the ages of Anton and his friends! 🧮\n")


    anton = 21
    beth = anton + 6
    chen = beth + 20
    drew = chen + anton
    ethan = chen

    print(f"👦 Anton is {anton} years old.")
    print(f"👩 Beth is {beth} years old.")
    print(f"🧓 Chen is {chen} years old.")
    print(f"👨 Drew is {drew} years old.")
    print(f"👦 Ethan is {ethan} years old.")

    print("🎈 Wow! That was fun! Now you know their ages! 🎊")


if __name__ == "__main__":
    main()
# Out:
# 🎉 Welcome to the Age Riddle Solver! 🤔📅
# Let's calculate the ages of Anton and his friends! 🧮
#
# 👦 Anton is 21 years old.
# 👩 Beth is 27 years old.
# 🧓 Chen is 47 years old.
# 👨 Drew is 68 years old.
# 👦 Ethan is 47 years old.
# 🎈 Wow! That was fun! Now you know their ages! 🎊
