# %% [markdown]
# **01_dicesimulator.md**

# %%
import random


total_rolls = 3

def roll_dice():
    """Simulates rolling two dice and prints the results."""

    die1 = random.randint(1, 6)
    die2 = random.randint(1, 6)
    total = die1 + die2

    print(f"🎲 Dice Roll: {die1} & {die2} ➝ Total: {total}")

    return die1, die2, total

def main():
    print("🎲 Welcome to the Dice Duel! 🎲")
    print(f"You will roll two dice {total_rolls} times. Let's begin!\n")

    for roll in range(1, total_rolls + 1):
        print(f"🔹 Roll {roll}:")
        roll_dice()
        print("-" * 20)

    print("\nGame Over! Hope you enjoyed the dice rolls. 🎉")


main()
# Out:
# 🎲 Welcome to the Dice Duel! 🎲
# You will roll two dice 3 times. Let's begin!
#
# 🔹 Roll 1:
# 🎲 Dice Roll: 1 & 6 ➝ Total: 7
# --------------------
# 🔹 Roll 2:
# 🎲 Dice Roll: 3 & 1 ➝ Total: 4
# --------------------
# 🔹 Roll 3:
# 🎲 Dice Roll: 1 & 5 ➝ Total: 6
# --------------------
#
# Game Over! Hope you enjoyed the dice rolls. 🎉
